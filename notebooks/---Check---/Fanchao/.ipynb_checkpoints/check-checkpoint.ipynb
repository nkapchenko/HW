# %%
import pandas as pd
import numpy as np
from numpy import array, median, sqrt
from hw import Jamshidian as jamsh
from hw import Henrard as henr
from hw import hw_helper
from hw import calibration as hw_calib
from hw.const import *
from fox_toolbox.utils import xml_parser, rates
from random import choice
import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 5.)})
sns.set_style("whitegrid")

np.set_printoptions(precision=2)

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Read IRSM FORM

# %%
irsmform, irsmout = [xml_parser.get_files(regex, 'monocurve') for regex in ['irsmform', 'irsmout']]

debug_df = pd.DataFrame()

# %%
main_curve, sprds = xml_parser.get_rate_curves(irsmform)
dsc_curve = main_curve

try:
    estim_curve = sprds[0]
except TypeError:
    estim_curve = main_curve

cal_basket = list(xml_parser.get_calib_basket(irsmform))
mr = xml_parser.get_hw_params(irsmform).meanR

# %% [markdown]
# ### READ IRSM OUT

# %%
ref_swos = list(xml_parser.get_calib_basket(irsmout))
ref_mr = mr

# %%
ref_sigmas = xml_parser.get_hw_params(irsmout).hw_volatility

# %% [markdown]
# ## Hernard pricer with its ref sigma

# %%
calib_premiumsH = []


for swo in cal_basket:

    henr_price, debug = henr.hw_swo(swo, ref_mr, ref_sigmas, dsc_curve, estim_curve)
    debug_df = pd.concat([debug_df, pd.DataFrame(data=debug)], sort=False)
    calib_premiumsH.append(henr_price)

calib_premiumsH
# Out:
# [0.0017855237853967032,
#  0.0022953529814707108,
#  0.002448987695905236,
#  0.002404157885418312,
#  0.002034635028439813,
#  0.0015233239456680647,
#  0.0008166148217094715]

# %%
cal_basket
# Out:
# [Swaption(0.2493150684932, Volatility(value=0.3305, type='SLN', shift_size=0.0), 0.2547945205479, array([0.26, 0.52, 0.77, 1.02, 1.27, 1.52, 1.77, 2.01]), array([0.01, 0.26, 0.26, 0.25, 0.25, 0.25, 0.26, 0.25]), 3),
#  Swaption(0.5013698630137, Volatility(value=0.35845, type='SLN', shift_size=0.0), 0.5068493150685, array([0.52, 0.77, 1.02, 1.27, 1.52, 1.77, 2.01]), array([0.01, 0.26, 0.25, 0.25, 0.25, 0.26, 0.25]), 3),
#  Swaption(0.7534246575342, Volatility(value=0.3821, type='SLN', shift_size=0.0), 0.758904109589, array([0.77, 1.02, 1.27, 1.52, 1.77, 2.01]), array([0.01, 0.25, 0.25, 0.25, 0.26, 0.25]), 3),
#  Swaption(1.0027397260274, Volatility(value=0.4141, type='SLN', shift_size=0.0), 1.0082191780822, array([1.02, 1.27, 1.52, 1.77, 2.01]), array([0.01, 0.25, 0.25, 0.26, 0.25]), 3),
#  Swaption(1.2493150684932, Volatility(value=0.4234780821918, type='SLN', shift_size=0.0), 1.2547945205479, array([1.27, 1.52, 1.77, 2.01]), array([0.01, 0.25, 0.26, 0.25]), 3),
#  Swaption(1.5013698630137, Volatility(value=0.4358230136986, type='SLN', shift_size=0.0), 1.5068493150685, array([1.52, 1.77, 2.01]), array([0.01, 0.26, 0.25]), 3),
#  Swaption(1.7534246575342, Volatility(value=0.4540706849315, type='SLN', shift_size=0.0), 1.7671232876712, array([2.01]), array([0.25]), 3)]

# %% [markdown]
# ## HW Calibration

# %%
sigma_hw_henr, debug_H = hw_calib.calibrate_sigma_hw(cal_basket, ref_mr, dsc_curve, estim_curve, IsJamsh=False)
sigma_hw_henr
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-b3957f7ad9f0> in <module>()
# ----> 1 sigma_hw_henr, debug_H = hw_calib.calibrate_sigma_hw(cal_basket, ref_mr, dsc_curve, estim_curve, IsJamsh=False)
#       2 sigma_hw_henr
#
# c:\users\mkapchenko\dropbox\perso\github\hw\src\hw\calibration.py in calibrate_sigma_hw(cal_basket, a, curve, estim_curve, IsJamsh)
#      71         factor = (exp(2 * a * swo.expiry) - exp(2 * a * previous_expiry)) / (2 * a)
#      72
# ---> 73         vol0 = sigma_schrager(swo, previous_expiry, a, curve, estim_curve, var_hw)
#      74         tvar_schrager = c2 * (var_hw + vol0**2 * factor)
#      75         assert abs(mkt_var - tvar_schrager) < EPS, f'vol0 should match mkt var by default.'
#
# c:\users\mkapchenko\dropbox\perso\github\hw\src\hw\calibration.py in sigma_schrager(swo, previous_expiry, a, curve, estim_curve, previous_hw_var)
#     132
#     133     assert (mkt_variance - c**2 *  previous_hw_var) > 0,\
# --> 134     f'Lack of vol to match market total variance at T = {swo.expiry} \n market_variance {mkt_variance}\n hull white previous variance {c**2 * previous_hw_var}'
#     135
#     136     return sqrt( (mkt_variance - c**2 * previous_hw_var) / (factor * c ** 2) )
#
# AssertionError: Lack of vol to match market total variance at T = 0.5013698630137
#  market_variance 0.06441921002054811
#  hull white previous variance 0.17520809039716914

# %%
df = pd.DataFrame(debug_H)
df

# %%
df.mkt_var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a33b970db895> in <module>()
# ----> 1 df.mkt_var
#
# NameError: name 'df' is not defined

# %%
df.tvar_schrager

# %%
df.var_hw
# Out:
# 0    0.000004
# 1    0.000020
# 2    0.000051
# 3    0.000126
# Name: var_hw, dtype: float64

# %%
from collections import namedtuple
a = namedtuple('calib_debug', 'expiries sigma_hw schrager var_hw black_price')

# %%
len('expiries sigma_hw schrager var_hw black_price'.split())
# Out:
# 5

# %%
sigma_hw_henr.values - ref_sigmas.values
# Out:
# array([-8.62644092e-06, -8.62644092e-06,  4.16406928e-06, -1.16426641e-08,
#        -1.75553344e-08, -1.75553344e-08])

# %%
fig = plt.figure()
plt.figure(figsize=(15,5))

# plt.step(sigma_hw_jamsh.buckets, sigma_hw_jamsh.values, label = 'Jamshidian', marker='o', where='post')
plt.step(sigma_hw_henr.buckets[:-1],   sigma_hw_henr.values[:-1],   label = 'Henrard', marker='o', where='pre')
plt.step(ref_sigmas.buckets[:-1], ref_sigmas.values[:-1], label = 'ref log', marker='o', where='pre')

# plt.ylim(0)
plt.legend(loc='lower right')
plt.title('calibrated Hull White piecewise constant volatility')
plt.xlabel('expiries')
plt.ylabel('volatility')
# Out:
# Text(0, 0.5, 'volatility')

# %%
pricesH = []
for swo in cal_basket:
    henr_price, debug = henr.hw_swo(swo, ref_mr, sigma_hw_henr, dsc_curve, estim_curve)
    pricesH.append(henr_price)

# %%
pricesJ = []
for swo in cal_basket:
    jamsh_price, debug = jamsh.hw_swo(swo, ref_mr, sigma_hw_jamsh, dsc_curve, estim_curve)
    pricesJ.append(jamsh_price)

# %%
fig = plt.figure()
plt.figure(figsize=(20,10))

ref_calib_prices = [ref_swo.cal_premium for ref_swo in ref_swos]
black_prices = pd.DataFrame(data=debug_H).black_price

prices_dict = { 'Jamshidian (calibrated sigma)': array(pricesJ),
               
               'Henrard (calibrated sigma)':array(pricesH),
               'Henrard(<RefSigma>)': array(calib_premiumsH),
               
               '<CalibratedPrice>': array(ref_calib_prices),        
#                'Black': array(black_prices)
              }
              
for lbl, prices in prices_dict.items():
    plt.plot([swo.expiry for swo in cal_basket], prices - black_prices,  label = lbl, linestyle=choice([':', '--', '-.']), marker = 'o')

plt.title('Black difference ')
plt.legend(loc='lower right')

# %%
array(ref_calib_prices) - array(pricesH)
# Out:
# array([-1.87581124e-10, -4.05090027e-10, -1.71167913e-10, -9.00259901e-12])
