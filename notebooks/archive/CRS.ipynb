# %%
import numpy as np
from numpy import array, exp, sqrt
import pandas as pd
from copy import deepcopy
from fox_toolbox.utils import xml_parser, service, rates, volatility

import matplotlib.pyplot as plt
import matplotlib.cm as cm

import seaborn as sns
sns.set_context("poster")
sns.set(rc={'figure.figsize': (16, 9.)})
sns.set_style("whitegrid")

np.set_printoptions(precision=5)

% load_ext autoreload
% autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
form = xml_parser.get_files('CRS xml')

# %%
fed, (libor3m, tres) = xml_parser.get_rate_curves(form)

# %%
libor3m.plot
tres.plot
plt.legend()

# %%
libor_fwd = 0.0196455466921
ann = 3.7852833844220
tres_fwd = 0.0160808262806
k = 0.884906811930
T = 1.0054794520548
vol = 0.2009407437497
std = vol * sqrt(T)

# %%
volatility.ImpliedVol(price=2.86566465807867, F=libor_fwd, K=k)
# Out:
# ValueError: Premium is impossible

# %%
ann * volatility.BSPrice(libor_fwd, k, std, -1)
# Out:
# 3.27525909048898

# %%
0.2009407437497/T
# Out:
# 0.1998456988246324
